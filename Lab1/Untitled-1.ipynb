# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv("Data/stud.csv", sep=',')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("Data/stud.csv", sep=',')
#       2 df.head()
#
# File c:\Users\dorde\Anaconda3\envs\dave3625\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\dorde\Anaconda3\envs\dave3625\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\dorde\Anaconda3\envs\dave3625\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\dorde\Anaconda3\envs\dave3625\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\dorde\Anaconda3\envs\dave3625\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/stud.csv'

# %%
df.describe()
# Out:
#           StudentID  FinalGrade
# count     50.000000   49.000000
# mean   48969.820000   71.653061
# std    26870.066326   90.455917
# min    10736.000000   24.000000
# 25%    26666.500000   39.000000
# 50%    44292.000000   60.000000
# 75%    70400.250000   78.000000
# max    99823.000000  673.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   50 non-null     int64
#  1   Age         50 non-null     object
#  2   email       50 non-null     object
#  3   hrsStudy    50 non-null     object
#  4   FinalGrade  49 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
df
# Out:
#     StudentID  Age              email hrsStudy  FinalGrade
# 0       47412   20  s47412@oslomet.no        5        46.0
# 1       15077   22  s15077@oslomet.no        0        65.0
# 2       15467   27  s15467@oslomet.no        1        26.0
# 3       17907   21  s17907@oslomet.no        6        68.0
# 4       13352  333  s13352@oslomet.no        4        34.0
# 5       88403   29  s88403@oslomet.no       11        62.0
# 6       56387   32  s56387@oslomet.no        9        29.0
# 7       95648   23  s95648@oslomet.no        3        38.0
# 8       63176   20  s63176@oslomet.no        0        98.0
# 9       15406   31  s15406@oslomet.no        2        68.0
# 10      41908   24  s41908@oslomet.no        0        62.0
# 11      35600   30  s35600@oslomet.no       11        70.0
# 12      16171   25  s16171@oslomet.no       10        81.0
# 13      55586   24  s55586@oslomet.no        7        31.0
# 14      71505   23  s71505@oslomet.no        1        49.0
# 15      31235   33  s31235@oslomet.no        1        72.0
# 16      80811   21  s80811@oslomet.no        6        51.0
# 17      33041   21  s33041@oslomet.no        2        97.0
# 18      99823   23  s99823@oslomet.no       10        56.0
# 19      41092   33  s41092@oslomet.no       10        42.0
# 20      15976   32  s15976@oslomet.no        9        78.0
# 21      91520   33  s91520@oslomet.no        9        60.0
# 22      11758   33  s11758@oslomet.no        6        54.0
# 23      67086   22  s67086@oslomet.no       10        51.0
# 24      84127   20  s84127@oslomet.no        5        92.0
# 25      59109   32  s59109@oslomet.no        7        97.0
# 26      10736    2  s10736@oslomet.no       10         NaN
# 27      71581   25  s71581@oslomet.no        9        26.0
# 28      29254   22  s29254@oslomet.no       10        88.0
# 29      20161   22  s20161@oslomet.no       11        90.0
# 30      21523   31  s21523@oslomet.no                 51.0
# 31      66815   21  s66815@oslomet.no        8        35.0
# 32      26914   31  s26914@oslomet.no        9        93.0
# 33      58153  220  s58153@oslomet.no       10        35.0
# 34      58387   20  s58387@oslomet.no        9       673.0
# 35      44561   28  s44561@oslomet.no       10        78.0
# 36      84163   25  s84163@oslomet.no        7        71.0
# 37      26584   27  s26584@oslomet.no       10        31.0
# 38      74289   31  s74289@oslomet.no        6        45.0
# 39      30158   21  s30158@oslomet.no        3        37.0
# 40      25452   24  s25452@oslomet.no       10        41.0
# 41      92390       s92390@oslomet.no        2        35.0
# 42      83390   22  s83390@oslomet.no        7        88.0
# 43      32946   31  s32946@oslomet.no       10        24.0
# 44      44023   31  s44023@oslomet.no        6        83.0
# 45      62039   23  s62039@oslomet.no        4        46.0
# 46      42989   27  s42989@oslomet.no        0        80.0
# 47      85370   29  s85370@oslomet.no        2        77.0
# 48      63135   26  s63135@oslomet.no        9        39.0
# 49      28895   19  s28895@oslomet.no       10        68.0

# %%
df.isna().sum()
df=df.replace(r'^\s*$', np.nan, regex=True)

# %%
meanAge = df['Age'][df['Age'].notna()].mean()
meanAge
# Out:
# 4.127085986386372e+96

# %%
AgeCopy = df['Age'][df['Age'].notna()].astype(int)
AgeCopy.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 49 entries, 0 to 49
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 49 non-null     int32
# dtypes: int32(1)
# memory usage: 588.0 bytes

# %%
df['Age'] = AgeCopy
df
# Out:
#     StudentID    Age              email hrsStudy  FinalGrade
# 0       47412   20.0  s47412@oslomet.no        5        46.0
# 1       15077   22.0  s15077@oslomet.no        0        65.0
# 2       15467   27.0  s15467@oslomet.no        1        26.0
# 3       17907   21.0  s17907@oslomet.no        6        68.0
# 4       13352  333.0  s13352@oslomet.no        4        34.0
# 5       88403   29.0  s88403@oslomet.no       11        62.0
# 6       56387   32.0  s56387@oslomet.no        9        29.0
# 7       95648   23.0  s95648@oslomet.no        3        38.0
# 8       63176   20.0  s63176@oslomet.no        0        98.0
# 9       15406   31.0  s15406@oslomet.no        2        68.0
# 10      41908   24.0  s41908@oslomet.no        0        62.0
# 11      35600   30.0  s35600@oslomet.no       11        70.0
# 12      16171   25.0  s16171@oslomet.no       10        81.0
# 13      55586   24.0  s55586@oslomet.no        7        31.0
# 14      71505   23.0  s71505@oslomet.no        1        49.0
# 15      31235   33.0  s31235@oslomet.no        1        72.0
# 16      80811   21.0  s80811@oslomet.no        6        51.0
# 17      33041   21.0  s33041@oslomet.no        2        97.0
# 18      99823   23.0  s99823@oslomet.no       10        56.0
# 19      41092   33.0  s41092@oslomet.no       10        42.0
# 20      15976   32.0  s15976@oslomet.no        9        78.0
# 21      91520   33.0  s91520@oslomet.no        9        60.0
# 22      11758   33.0  s11758@oslomet.no        6        54.0
# 23      67086   22.0  s67086@oslomet.no       10        51.0
# 24      84127   20.0  s84127@oslomet.no        5        92.0
# 25      59109   32.0  s59109@oslomet.no        7        97.0
# 26      10736    2.0  s10736@oslomet.no       10         NaN
# 27      71581   25.0  s71581@oslomet.no        9        26.0
# 28      29254   22.0  s29254@oslomet.no       10        88.0
# 29      20161   22.0  s20161@oslomet.no       11        90.0
# 30      21523   31.0  s21523@oslomet.no      NaN        51.0
# 31      66815   21.0  s66815@oslomet.no        8        35.0
# 32      26914   31.0  s26914@oslomet.no        9        93.0
# 33      58153  220.0  s58153@oslomet.no       10        35.0
# 34      58387   20.0  s58387@oslomet.no        9       673.0
# 35      44561   28.0  s44561@oslomet.no       10        78.0
# 36      84163   25.0  s84163@oslomet.no        7        71.0
# 37      26584   27.0  s26584@oslomet.no       10        31.0
# 38      74289   31.0  s74289@oslomet.no        6        45.0
# 39      30158   21.0  s30158@oslomet.no        3        37.0
# 40      25452   24.0  s25452@oslomet.no       10        41.0
# 41      92390    NaN  s92390@oslomet.no        2        35.0
# 42      83390   22.0  s83390@oslomet.no        7        88.0
# 43      32946   31.0  s32946@oslomet.no       10        24.0
# 44      44023   31.0  s44023@oslomet.no        6        83.0
# 45      62039   23.0  s62039@oslomet.no        4        46.0
# 46      42989   27.0  s42989@oslomet.no        0        80.0
# 47      85370   29.0  s85370@oslomet.no        2        77.0
# 48      63135   26.0  s63135@oslomet.no        9        39.0
# 49      28895   19.0  s28895@oslomet.no       10        68.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   50 non-null     int64
#  1   Age         49 non-null     float64
#  2   email       50 non-null     object
#  3   hrsStudy    49 non-null     object
#  4   FinalGrade  49 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df['Age'].fillna(AgeCopy.mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   50 non-null     int64
#  1   Age         50 non-null     float64
#  2   email       50 non-null     object
#  3   hrsStudy    49 non-null     object
#  4   FinalGrade  49 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
meanHrs = df['hrsStudy'][df['hrsStudy'].notna()].mean()
meanHrs


#hrsCopy = df['hrsStudy'][]
# Out:
# 1.0237575367757369e+62

# %%
hrsCopy = df['hrsStudy'][df['hrsStudy'].notna()].astype(int)
df['hrsStudy'] = hrsCopy
df['hrsStudy'].fillna(hrsCopy.mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   50 non-null     int64
#  1   Age         50 non-null     float64
#  2   email       50 non-null     object
#  3   hrsStudy    50 non-null     float64
#  4   FinalGrade  49 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
tenHours = df['FinalGrade'][df['hrsStudy'] == 10].mean()
tenHours
# Out:
# 54.09090909090909

# %%
df['FinalGrade'].fillna(tenHours, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   50 non-null     int64
#  1   Age         50 non-null     float64
#  2   email       50 non-null     object
#  3   hrsStudy    50 non-null     float64
#  4   FinalGrade  50 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
df["FinalGrade"].plot.box()
# Out:
# <Axes: >

# %%
df.groupby('hrsStudy')['FinalGrade'].mean().plot(kind='bar')
plt.xlabel('Hours Studied')
plt.ylabel('Average Final Grade')
# Out:
# Text(0, 0.5, 'Average Final Grade')
